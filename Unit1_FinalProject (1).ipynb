# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Let's map some earthquakes!
#
# Use this notebook to complete your final project for unit 1. You'll use a "for loop" and conditionals to select the right earthquakes to plot on your map and discover something about the seismic activity in your region.

# %% [markdown]
# ## Data Setup
# In this section we'll open up our data file and turn it into a list of lists that we can work with using "for loops".

# %% [markdown]
# We'll be making a graph, so import the matplotlib.pyplot library with the alias plt:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Next, we will open the data file using the open() function and then skip the first row using the .readline() function:

# %%
all_quakes = open("/content/drive/My Drive/quakes_project.txt")
all_quakes.readline()

# The \t in between each column name lets you know that this text file is separated by tabs
# Out:
# 'YEAR\tFOCAL_DEPTH\tEQ_PRIMARY\tCOUNTRY\tSTATE\tLOCATION_NAME\tLATITUDE\tLONGITUDE\tREGION_CODE\tDEATHS\tDAMAGE_MILLIONS_DOLLARS\tHOUSES_DESTROYED\tHOUSES_DESTROYED_DESCRIPTION\tHOUSES_DAMAGED\n'

# %% [markdown]
# Currently our file is one long string. Let's make each line of the data file a list and put all of those lists into one big list called quakes_list.

# %%
quakes_list = []
for i in all_quakes:
    quakes_list.append(i.split('\t')) # The .split() method separates the items in each line

# %% [markdown]
# Print out the length of quakes_list to see how many earthquakes are in our data file:

# %%
print(len(quakes_list))
# Out:
# 4596

# %% [markdown]
# ## Selecting your data
# In this section you'll decide which data you need for your project. You'll use "for loops" and conditionals to select the right data.

# %% [markdown]
# You will need latitudes and longitudes for your scatter plot, so create two empty lists to hold those values:

# %%
quakes_latitudes = []
quakes_longitudes = []

# %% [markdown]
# Next, decide as a group what range of years you want to look at (between 1800 and 2018). You should base your decision on the research you did on the seismic activity in your region.

# %% [markdown]
# You'll also need to know the "region code" for your region:
# - Africa: 10
# - Central America: 100
# - Central and South Pacific: 170
# - North America: 150
# - South America: 160

# %% [markdown]
# Create a "for loop" that loops through the lines in quakes_list and appends the latitute and longitude to the lists you created above **if** the earthquake for that row occurred in your region and during your year range.
#
# Hints:
# - You can nest an if statement inside another if statement
# - You can compare a value to two other values like this: 5 < x < 10

# %%
for i in quakes_list:
  if int(i[8]) == 150:
    if 1900 <= int(i[0]) <= 2020:
      quakes_latitudes.append(float(i[6]))
      quakes_longitudes.append(float(i[7]))

# %% [markdown]
# nt out the length of your latitude and longitude lists. Does this result make sense?

# %%
print(quakes_latitudes)
print(quakes_longitudes)
# Out:
# [57.09, 58.6, 20.0, 20.0, 51.45, 36.0, 52.4, 34.5, 29.0, 17.6, 16.6, 61.56, 16.7, 15.0, 64.66, 50.73, 20.3, 56.85, 37.67, 19.0, 51.05, 52.59, 59.5, 28.0, 17.0, 19.0, 61.0, 17.0, 18.0, 17.0, 16.8, 52.0, 16.8, 60.5, 17.5, 17.0, 57.5, 20.4, 19.9, 19.9, 16.8, 40.5, 32.8, 53.3, 48.5, 54.79, 15.0, 33.7, 19.26, 19.7, 41.0, 40.8, 60.0, 34.418, 46.4, 18.5, 20.5, 57.69, 34.813, 32.5, 49.0, 17.8, 17.75, 16.028, 16.0, 15.67, 51.0, 51.0, 42.9, 44.69, 52.5, 34.03, 16.1, 38.7, 19.0, 19.5, 19.452, 33.62, 73.122, 31.8, 18.5, 46.6, 46.6, 16.5, 17.3, 16.7, 18.8, 55.48, 52.2, 18.2, 16.1, 32.733, 52.0, 40.5, 18.9, 16.3, 16.7, 44.957, 51.5, 53.492, 49.87, 35.0, 54.5, 22.0, 53.62, 47.167, 33.75, 16.5, 16.48, 19.7, 33.5, 16.1, 19.11, 35.0, 35.333, 39.4, 39.6, 39.3, 17.3, 33.8, 17.0, 51.292, 55.0, 16.5, 58.37, 44.712, 17.0, 18.3, 34.0, 52.47, 41.8, 17.2, 17.2, 61.017, 18.3, 53.03, 47.4, 16.3, 50.32, 51.29, 16.5, 15.5, 38.467, 57.5, 51.8, 51.4, 34.412, 51.5, 56.82, 19.936, 34.1, 18.48, 18.27, 19.451, 39.439, 42.06, 53.11, 17.4, 34.35, 17.03, 16.01, 60.691, 32.634, 17.813, 41.117, 46.214, 37.855, 37.6, 32.22, 18.211, 38.174, 33.133, 18.048, 16.558, 17.25, 46.975, 19.43, 61.031, 36.219, 43.974, 16.147, 37.32, 42.375, 18.19, 17.802, 51.52, 52.327, 37.537, 32.97, 34.0, 58.586, 58.679, 34.07, 34.061, 33.082, 57.262, 48.117, 55.543, 19.362, 37.036, 16.773, 34.14, 40.235, 34.262, 40.368, 34.203, 34.201, 33.961, 36.705, 45.035, 42.314, 40.402, 40.741, 34.213, 42.762, 40.33, 65.17, 19.055, 16.779, 51.564, 51.478, 15.978, 18.219, 15.883, 34.594, 18.324, 18.386, 16.059, 38.379, 52.63, 47.149, 34.059, 63.514, 63.517, 32.319, 16.87, 18.194, 44.513, 35.706, 34.31, 18.77, 36.87, 34.494, 51.146, 49.277, 35.819, 17.488, 41.301, 45.365, 19.878, 51.307, 37.804, 37.434, 45.394, 39.465, 39.464, 17.302, 39.52, 33.953, 32.456, 41.153, 38.452, 32.437, 40.652, 32.7, 32.297, 16.396, 35.827, 45.88, 52.05, 52.171, 38.947, 37.063, 17.844, 35.531, 35.532, 37.936, 52.788, 16.493, 55.393, 16.878, 31.817, 58.306, 38.216, 33.863, 17.397, 17.235, 35.937, 35.524, 17.682, 14.728, 51.849, 52.214, 15.802, 59.658, 35.984, 59.844, 18.584, 16.737, 15.022, 19.37, 56.046, 16.646]
# [-153.48, -137.5, -105.0, -105.0, -171.02, -120.5, -167.5, -120.5, -114.0, -99.7, -92.6, -158.54, -99.2, -98.0, -148.08, -178.55, -103.4, -153.9, -122.48, -113.8, 179.69, -169.73, -135.5, -112.5, -100.0, -155.0, -146.2, -101.0, -99.0, -101.2, -99.8, 175.0, -95.9, -149.0, -102.5, -100.7, -155.0, -103.2, -99.9, -99.8, -92.2, -117.5, -115.5, -170.0, 178.5, -169.12, -97.0, -117.0, -96.97, -104.3, -125.5, -124.5, -146.0, -120.196, -111.24, -107.0, -155.5, -136.07, -120.774, -115.5, -125.0, -97.6, -97.1, -97.036, -97.0, -96.1, -170.0, -131.0, -78.3, -56.0, 171.5, -118.643, -96.8, -117.8, -104.5, -104.25, -103.632, -117.97, -70.014, -115.5, -105.5, -112.0, -112.0, -93.1, -99.3, -98.5, -97.5, -158.37, -131.9, -99.5, -98.3, -115.5, 178.2, -125.25, -102.9, -95.0, -101.5, -74.723, -174.5, -162.832, -124.92, -116.6, -161.0, -106.0, -133.27, -122.617, -118.25, -100.4, -98.22, -156.0, -118.2, -96.8, -155.033, -119.017, -118.917, -118.5, -118.5, -118.2, -92.6, -118.2, -99.5, -175.629, -165.2, -99.1, -136.665, -111.215, -96.3, -94.4, -118.0, -168.54, -111.8, -99.6, -99.5, -147.648, -100.4, -167.55, -122.3, -95.8, 177.93, 178.55, -97.8, -92.7, -122.692, -153.9, -131.0, -177.2, -118.4, 179.1, -135.68, -155.098, -119.0, -103.0, -96.6, -155.033, -121.528, -112.55, 173.5, -100.64, -119.7, -99.74, -96.591, -141.671, -115.324, -101.276, -124.253, -122.194, -121.816, -118.84, -114.985, -98.24, -83.907, -115.65, -102.084, -98.358, -93.21, -66.659, -155.454, -147.286, -120.317, -113.916, -95.232, -121.698, -105.72, -102.533, -101.647, -174.776, -174.504, -118.447, -117.869, -116.61, -143.27, -142.786, -118.1, -118.078, -115.775, -142.747, -71.183, -156.835, -155.083, -121.883, -99.328, -117.7, -124.348, -118.002, -124.316, -116.827, -116.436, -116.318, -116.293, -122.607, -122.012, -125.68, -124.31, -118.537, -110.976, -76.037, -148.565, -104.205, -98.597, -177.632, -176.847, -98.07, -102.756, -96.298, -116.271, -101.539, -97.436, -96.931, -122.413, -132.2, -122.727, -118.387, -147.912, -147.444, -115.322, -100.113, -95.908, -73.699, -121.102, -116.848, -104.104, -88.98, -85.629, 178.65, -128.772, -120.364, -101.303, -125.97, -112.615, -155.935, -179.971, -122.193, -121.774, -112.13, -111.237, -111.207, -100.198, -119.93, -117.761, -115.315, -114.867, -87.886, -115.165, -124.692, -115.921, -115.278, -97.782, -96.772, -75.48, -171.836, -171.708, -107.497, -104.701, -99.963, -96.788, -96.765, -77.933, -132.101, -98.231, -134.652, -99.498, -97.088, -136.96, -122.312, -117.835, -100.972, -100.746, -97.271, -97.146, -95.653, -92.578, 178.735, -169.399, -93.633, -153.452, -96.798, -136.695, -98.399, -94.946, -93.899, -155.032, -149.073, -97.653]

# %% [markdown]
# ## Making your graph
# Now that you've created lists with your x data (longitude) and y data (latitude) it's time to make a scatter plot!

# %% [markdown]
# Replace the coordinates in plt.xlim and plt.ylim functions below as follows:
# - Africa: x = (-25,50), y = (-40,45)
# - Central America: x = (-100,-70), y = (0,25)
# - Central and South Pacific: x = (80,180), y = (-70,30)
# - North America: x = (-180,-50), y = (0,90)
# - South America: x = (-120,-20), y = (-60,20)

# %%
# This function clears any leftover plots
plt.clf()

# This code adds an image behind your plot
image = plt.imread("/content/drive/My Drive/Colab Notebooks/earth.jpg")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])

# This code crops the image to show only your region. 
# IMPORTANT: Replace the coordinates in plt.xlim and plt.ylim functions
# To match your region using the key above
plt.xlim(-180,-50)
plt.ylim(0,90)

# Create a scatter plot using plt.scatter(). 
# You can change the size, shape, and color of your markers! 
# Try adding s = #, marker = "symbol", and c = "color"

# Don't forget plt.show()!
plt.scatter(quakes_longitudes, quakes_latitudes, label = "Latitude and Longitude of Earthquakes in North America", s= 50, marker ="x")
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.title("Latitude vs. Longitude of Earthquakes in North America")
plt.legend()
plt.show()

# %% [markdown]
# ### Modify the points on your graph!
# You can find the complete list of possible markers here: https://matplotlib.org/api/markers_api.html
#
# and the possible colors here: https://i.stack.imgur.com/lFZum.png

# %% [markdown]
# ### Download your graph
#
# When you're happy with your graph, you can download it to your computer using the plt.savefig() function. This function takes two arguments: whatever you'd like to name the file in a string (ex: "quakes_graph.png") and dpi=1000. The file will be downloaded to the same folder as the Jupyter Notebook file.
#
# **Note: You will need to comment out plt.show() and rerun your graphing code before running plt.savefig().**
#
# plt.show() outputs the graph and prevents you from downloading it to your computer.

# %%
plt.savefig("quakes_graph.png", dpi = 1000)

# %% [markdown]
# ## Mapping tectonic plate boundaries
# Copy and paste all your graphing code in the cell below. Then change replace **image = plt.imread("earth.jpg")** with **image = plt.imread("plates.png")**
#
# Run your code and examine the results! Do you see what you expect?

# %%
# This function clears any leftover plots
plt.clf()

# This code adds an image behind your plot
image = plt.imread("/content/drive/My Drive/plates.png")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])

# This code crops the image to show only your region. 
# IMPORTANT: Replace the coordinates in plt.xlim and plt.ylim functions
# To match your region using the key above
plt.xlim(-180,-50)
plt.ylim(0,90)

# Create a scatter plot using plt.scatter(). 
# You can change the size, shape, and color of your markers! 
# Try adding s = #, marker = "symbol", and c = "color"

# Don't forget plt.show()!
plt.scatter(quakes_longitudes, quakes_latitudes, label = "Latitude and Longitude of Earthquakes in North America", c = "orange")
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.title("Latitude vs. Longitude of Earthquakes in North America")
plt.legend()
plt.show()
